# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Intro-to-Folium" data-toc-modified-id="Intro-to-Folium-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>Intro to Folium</a></span></li><li><span><a href="#Primerito-Mapa" data-toc-modified-id="Primerito-Mapa-0.2"><span class="toc-item-num">0.2&nbsp;&nbsp;</span>Primerito Mapa</a></span></li><li><span><a href="#Marker" data-toc-modified-id="Marker-0.3"><span class="toc-item-num">0.3&nbsp;&nbsp;</span>Marker</a></span></li><li><span><a href="#Diferentes-sintaxis-a-la-hora-de-meter-un-marker-tuneando-el-ICONO" data-toc-modified-id="Diferentes-sintaxis-a-la-hora-de-meter-un-marker-tuneando-el-ICONO-0.4"><span class="toc-item-num">0.4&nbsp;&nbsp;</span>Diferentes sintaxis a la hora de meter un marker tuneando el ICONO</a></span></li></ul></li><li><span><a href="#Lista-de-colores-de-los-iconos-👀" data-toc-modified-id="Lista-de-colores-de-los-iconos-👀-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Lista de colores de los iconos 👀</a></span><ul class="toc-item"><li><span><a href="#Markers,-muchos-markers,-todos-los-markers-a-la-vez-🚀" data-toc-modified-id="Markers,-muchos-markers,-todos-los-markers-a-la-vez-🚀-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Markers, muchos markers, todos los markers a la vez 🚀</a></span></li><li><span><a href="#Mapa-de-Calor" data-toc-modified-id="Mapa-de-Calor-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Mapa de Calor</a></span></li><li><span><a href="#Creamos-el-mapa-básico-al-que-después-le-añadimos-las-capas" data-toc-modified-id="Creamos-el-mapa-básico-al-que-después-le-añadimos-las-capas-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Creamos el mapa básico al que después le añadimos las capas</a></span></li><li><span><a href="#Hacemos-un-subset-del-dataframe-por-capa" data-toc-modified-id="Hacemos-un-subset-del-dataframe-por-capa-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Hacemos un subset del dataframe por capa</a></span></li><li><span><a href="#Creamos-La-FeatureGroup" data-toc-modified-id="Creamos-La-FeatureGroup-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Creamos La FeatureGroup</a></span></li><li><span><a href="#Creamos-la-capa-HeatMap-y-la-añadimos-a-la-FeatureGroup" data-toc-modified-id="Creamos-la-capa-HeatMap-y-la-añadimos-a-la-FeatureGroup-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Creamos la capa HeatMap y la añadimos a la FeatureGroup</a></span></li><li><span><a href="#Añadimos-la-FeatureGrup-con-heatmap-y-name-al-mapa" data-toc-modified-id="Añadimos-la-FeatureGrup-con-heatmap-y-name-al-mapa-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Añadimos la FeatureGrup con heatmap y name al mapa</a></span></li><li><span><a href="#Añadimos-la-tarde" data-toc-modified-id="Añadimos-la-tarde-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>Añadimos la tarde</a></span></li><li><span><a href="#Capa-Noche" data-toc-modified-id="Capa-Noche-1.9"><span class="toc-item-num">1.9&nbsp;&nbsp;</span>Capa Noche</a></span></li><li><span><a href="#Podemos-guardar-muestros-mapas" data-toc-modified-id="Podemos-guardar-muestros-mapas-1.10"><span class="toc-item-num">1.10&nbsp;&nbsp;</span>Podemos guardar muestros mapas</a></span></li></ul></li></ul></div>

# %% [markdown]
# ### Intro to Folium

# %% [markdown]
# ![mapa](../images/geo_portada.jpg)

# %% [markdown]
# Lo primerito será siempre leer la documentación ¿no? PLS :cobete: :músculo: :fueguito:
# - https://python-visualization.github.io/folium/

# %%
#!pip install folium

# %%
import folium
from folium import Choropleth, Circle, Marker, Icon, Map
from folium.plugins import HeatMap, MarkerCluster
import pandas as pd

# %%
inicial_lat = 40.4143851
inicial_long = -3.6820241

# %% [markdown]
# ### Primerito Mapa

# %% [markdown]
# Creamos un mapa básico a raíz de unas coordenadas con un zoom inicial

# %%
#mapa aquí :) 
map_1 = folium.Map(location=[inicial_lat,inicial_long], zoom_start=15)
map_1;

# %% [markdown]
# ### Marker

# %% [markdown]
# Os dejo por aquí la doc concreta de los marker
# - https://python-visualization.github.io/folium/modules.html?highlight=marker

# %% [markdown]
# Para añadir markers en un mapa, tendremos que "añadir" elementos a dicho mapa, por eso, vamos a añadirlos al mapa anterior llamado map_1.

# %%
#Marker Parque de Dobby
parque = folium.Marker(location=[inicial_lat, inicial_long], tooltip = "Parque de Dobby")
#Añado el marker al mapa
parque.add_to(map_1)

# %%
map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_0268e67550d5443bbc661179cf7835a8%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_0268e67550d5443bbc661179cf7835a8%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_0268e67550d5443bbc661179cf7835a8%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_0268e67550d5443bbc661179cf7835a8%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.4143851%2C%20-3.6820241%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# Añadimos otro Marker y vemos que le podemos cambiar el icono y el color de fondo y del icono.

# %%
#Ubicación de la casa de Dobby
lavapi_lat = 40.408808
lavapi_long = -3.7034796

# %% [markdown]
# Pero...wait ¿quién es Dobby?

# %% [markdown]
# ![mapa](../images/dobby.jpeg)

# %% [markdown]
# Para modificar los iconos ¿de dónde los sacamos?
# - https://fontawesome.com/v4.7.0/icons/ --> Si quiero usar estos pongo prefix="fa" (Font Awesome)
# - https://getbootstrap.com/docs/3.3/components/ --> Built in no hace falta meter prefix

# %% [markdown]
# ### Diferentes sintaxis a la hora de meter un marker tuneando el ICONO

# %% [markdown]
# Primerita forma de añadir un marker tuneado al mapa

# %%
# Guardamos el icono como una variable
#prefix = fa lo ponemos cuando usemos los iconos de fontawesome.
icono = Icon(color="green",
             opacity=0.3,
             prefix = "fa",
             icon="paw",
             icon_color="black",)

# %%
# Le añadimos el parámetro icon al marker de antes pasándole el icono que hemos guardado en la variable
marker_uno = Marker(location=[40.408703, -3.7034783], tooltip = "Casa de Dobby", icon=icono)

# %%
marker_uno.add_to(map_1)
map_1;

# %% [markdown]
# Segunda forma de añadir un marker tuneado al mapa

# %%
# El icono siempre lo voy a crear a parte
icono2 = Icon(color="red",
             opacity=0.3,
             prefix = "fa",
             icon="camera",
             icon_color="black",)

# %%
# Guardamos lat, lon y tooltip en un diccionario y le pasamos al marker los parámetros como kwargs
sol_lat= 40.4146500
sol_lon = -3.7004000
diccionario = {"location":[sol_lat, sol_lon], "tooltip":"Dobby se hace fotos", "icon":icono2}

# %%
marker_dos = Marker(**diccionario)

# %%
marker_dos.add_to(map_1)

# %%
map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_0268e67550d5443bbc661179cf7835a8%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_0268e67550d5443bbc661179cf7835a8%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_0268e67550d5443bbc661179cf7835a8%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_0268e67550d5443bbc661179cf7835a8%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.4143851%2C%20-3.6820241%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# Kwargs --> https://book.pythontips.com/en/latest/args_and_kwargs.html
# https://j2logo.com/args-y-kwargs-en-python/

# %% [markdown]
# ## Lista de colores de los iconos 👀
# ```python
# [‘red’, ‘blue’, ‘green’, ‘purple’, ‘orange’, ‘darkred’,
# ’lightred’, ‘beige’, ‘darkblue’, ‘darkgreen’, ‘cadetblue’, ‘darkpurple’, ‘white’, ‘pink’, ‘lightblue’, ‘lightgreen’, ‘gray’, ‘black’, ‘lightgray’]
# ```

# %%
#añadimos el marker al mapa original donde ya teníamos el parque de Dobby guardado

# %% [markdown]
# ### Markers, muchos markers, todos los markers a la vez 🚀

# %% [markdown]
# Para enseñar este ejemplo, utilizamos un dataset donde tenemos ya unas columnas de latitud y longitud

# %%
df = pd.read_csv('../datasets/bici_clean.csv')

# %%
df.head()
# Out:
#                  fecha                  dia  year horario festividad  \
# 0  2019-01-01 14:00:00  2019-01-01 00:00:00  2019   Tarde    Festivo
# 1  2019-01-02 21:00:00  2019-01-02 00:00:00  2019   Noche  Laborable
# 2  2019-01-03 14:00:00  2019-01-03 00:00:00  2019   Tarde  Laborable
# 3  2019-01-03 13:00:00  2019-01-03 00:00:00  2019   Tarde  Laborable
# 4  2019-01-03 13:00:00  2019-01-03 00:00:00  2019   Tarde  Laborable
#
#   tipo_accidente lesividad      meteo           distrito  \
# 0       Colision  Moderada  Despejado          SALAMANCA
# 1       Colision     Grave  Despejado          HORTALEZA
# 2       Colision      Leve  Despejado  VILLA DE VALLECAS
# 3       Colision      Leve  Despejado  VILLA DE VALLECAS
# 4       Colision      Leve  Despejado  VILLA DE VALLECAS
#
#                                            direccion       lon        lat
# 0  CALLE CASTELLO / CALLE DON RAMON DE LA CRUZ Ma... -3.681209  40.428990
# 1  AVDA. GRAN VIA DE HORTALEZA / GTA. LUIS ROSALE... -3.654527  40.466921
# 2                     CALLE FELIPE ALVAREZ 10 Madrid -3.623423  40.381971
# 3  AVDA. SANTA EUGENIA / CALLE REAL DE ARGANDA Ma... -3.608276  40.377939
# 4  AVDA. SANTA EUGENIA / CALLE REAL DE ARGANDA Ma... -3.608276  40.377939

# %%
df.shape
# Out:
# (2197, 12)

# %%
df.festividad.unique()
# Out:
# array(['Festivo', 'Laborable', 'Vispera'], dtype=object)

# %%
# Como hay muchos datos y estamos haciendo pruebas, vamos a quedarnos solo con los de 2019

# %%
df2019 = df[df["year"] == 2019]

# %%
#¿Cuántas clasificaciones de festividad hay?

# %%
df2019.festividad.unique()
# Out:
# array(['Festivo', 'Laborable', 'Vispera'], dtype=object)

# %%
df2019.head()
# Out:
#                  fecha                  dia  year horario festividad  \
# 0  2019-01-01 14:00:00  2019-01-01 00:00:00  2019   Tarde    Festivo
# 1  2019-01-02 21:00:00  2019-01-02 00:00:00  2019   Noche  Laborable
# 2  2019-01-03 14:00:00  2019-01-03 00:00:00  2019   Tarde  Laborable
# 3  2019-01-03 13:00:00  2019-01-03 00:00:00  2019   Tarde  Laborable
# 4  2019-01-03 13:00:00  2019-01-03 00:00:00  2019   Tarde  Laborable
#
#   tipo_accidente lesividad      meteo           distrito  \
# 0       Colision  Moderada  Despejado          SALAMANCA
# 1       Colision     Grave  Despejado          HORTALEZA
# 2       Colision      Leve  Despejado  VILLA DE VALLECAS
# 3       Colision      Leve  Despejado  VILLA DE VALLECAS
# 4       Colision      Leve  Despejado  VILLA DE VALLECAS
#
#                                            direccion       lon        lat
# 0  CALLE CASTELLO / CALLE DON RAMON DE LA CRUZ Ma... -3.681209  40.428990
# 1  AVDA. GRAN VIA DE HORTALEZA / GTA. LUIS ROSALE... -3.654527  40.466921
# 2                     CALLE FELIPE ALVAREZ 10 Madrid -3.623423  40.381971
# 3  AVDA. SANTA EUGENIA / CALLE REAL DE ARGANDA Ma... -3.608276  40.377939
# 4  AVDA. SANTA EUGENIA / CALLE REAL DE ARGANDA Ma... -3.608276  40.377939

# %% [markdown]
# Vamos a iterar sobre todas las filas del dataframe buscando qué hay dentro de cada fila en la columna.
# Pondremos un icono a los accidentes en función de la columna "festivo"
# Pero tendremos que guardar las configuraciones y añadir el Marker al final y todo esto dentro de un bucle 🤭🤯
# - Primero la config del tooltip
# - Después el iconito en función del festivo
# - Por último añadir cada marker
#
# Keep Calm, lo vemos 🙃

# %%
#Bueno, recordad que lo primerito es crear un mapa base al que añadimos cosas

# %%
map_2 = Map(location = [40.428990,-3.681209], zoom_start = 15)
map_2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_290e6c7eee8c47569ba74dafc147b6c0%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_290e6c7eee8c47569ba74dafc147b6c0%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_290e6c7eee8c47569ba74dafc147b6c0%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_290e6c7eee8c47569ba74dafc147b6c0%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.42899%2C%20-3.681209%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
lista = ["a", "b", "c"]
for i,elemento in enumerate(lista):
    print(i,elemento)
# Out:
# 0 a
# 1 b
# 2 c

# %%
for i,row in df2019.iterrows():
    distrito = {"location": [row["lat"], row["lon"]], "tooltip": row["distrito"]}
    
    if row["festividad"] == "Laborable":
        icono = Icon(color = "red",
                     prefix="fa",
                     icon="laptop",
                     icon_color="black"
        )
    elif row["festividad"] == "Vispera":
        icono = Icon(color = "green",
                     prefix="fa",
                     icon="glass",
                     icon_color="black")
        
    elif row["festividad"] == "Festivo":
        icono = Icon(color = "cadetblue",
                     prefix="fa",
                     icon="bug",
                     icon_color="black")
        
    mark = Marker(**distrito, icon=icono)
    mark.add_to(map_2)
map_2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_290e6c7eee8c47569ba74dafc147b6c0%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_290e6c7eee8c47569ba74dafc147b6c0%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_290e6c7eee8c47569ba74dafc147b6c0%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_290e6c7eee8c47569ba74dafc147b6c0%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.42899%2C%20-3.681209%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
df2019.sample()
# Out:
#                    fecha                  dia  year horario festividad  \
# 515  2019-08-15 17:00:00  2019-08-15 00:00:00  2019   Tarde    Festivo
#
#     tipo_accidente lesividad      meteo             distrito  \
# 515       Colision  Moderada  Despejado  SAN BLAS-CANILLEJAS
#
#                       direccion       lon        lat
# 515  GLORIETA SOBRE M-40 Madrid -3.697028  40.364539

# %% [markdown]
# ¿Es el mejor modo de visualizar esto? Hemos creado un mapa con infinitos Markers...mazo de markers...pero ¿Hay otro modo de visualizar esta información un poquito mejor?
# Cuando tenemos muchos datos agrupados 🗺

# %% [markdown]
# ### Mapa de Calor

# %% [markdown]
# Vamos a comprobar cuántas categorías hay en la columna de horario, para hacer un mapa de calor. Primero hacemos un mapa con el horario de mañana, y después añadimos el horario de tarde con el Layer Control.
# Allá vamos 🔥

# %% [markdown]
# ### Creamos el mapa básico al que después le añadimos las capas

# %%
map_3 = Map(location = [40.428990,-3.681209], zoom_start=15)
map_3

# %% [markdown]
# ### Hacemos un subset del dataframe por capa

# %%
morning = df[df["horario"]=="Mañana"]
morning.sample()

# %% [markdown]
# ### Creamos La FeatureGroup

# %%
morning_group = folium.FeatureGroup(name="Mañana")

# %% [markdown]
# ### Creamos la capa HeatMap y la añadimos a la FeatureGroup

# %%
HeatMap(data=morning[["lat", "lon"]], radius=15).add_to(morning_group)

# %% [markdown]
# ### Añadimos la FeatureGrup con heatmap y name al mapa

# %%
morning_group.add_to(map_3)
map_3

# %% [markdown]
# ### Añadimos la tarde

# %%
tarde = df[df["horario"]=="Tarde"]
tarde.sample()

# %%
tarde_group = folium.FeatureGroup("Tarde")
HeatMap(data=tarde[["lat", "lon"]], radius=15).add_to(tarde_group)
tarde_group.add_to(map_3)

# %%
map_3

# %%
# VOY A AÑADIR LA LEYENDA PERO LUEGO TENGO QUE REINICIAR EL KERNEL PARA AÑADIR LA NOCHE
#folium.LayerControl(collapsed=False).add_to(map_3)

# %%
#folium.LayerControl(collapsed=True).add_to(map_3)

# %% [markdown]
# ### Capa Noche

# %%
noche = df[df["horario"] == "Noche"]
noche.sample()

# %%
# LAYER CONTROL AL FINAL, AÑADE LA LEYENDA INTERACTIVA QUE PERMITE INTERACTUAR CON LAS CAPAS

# %%
noche_group = folium.FeatureGroup(name="Noche")
HeatMap(data=df[["lat", "lon"]], radius=15).add_to(noche_group)
noche_group.add_to(map_3)
map_3

# %%
folium.LayerControl(collapsed=False).add_to(map_3) #La Leyenda de arriba con collapsed = False

# %%
map_3

# %%
"""
Collapsed hace que la leyenda esté recogida si lo pongo a True o que se vea directamente si lo pongo a false.
"""

# %% [markdown]
# ### Podemos guardar muestros mapas

# %%
map_3.save("primerito mapa")
